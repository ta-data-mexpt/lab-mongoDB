# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
client=MongoClient('mongodb+srv://aimee:prueba@cluster0-4qikj.gcp.mongodb.net/db_companies?retryWrites=true&w=majority')
db=client.db_companies

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
print(list(db['companies'].find({'name':'Babelgum'},{'name':1,'_id':0})))
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
list(db['companies'].find(filter={'number_of_employees':{'$gt':5000}},sort=[('number_of_employees',1)],limit=20,projection={'name':1,'_id':0}))
# Out:
# [{'name': 'Nintendo'},
#  {'name': 'Hexaware Technologies'},
#  {'name': 'Facebook'},
#  {'name': 'OpenText'},
#  {'name': 'LSI'},
#  {'name': 'CPM Braxis'},
#  {'name': 'Microchip Technologies'},
#  {'name': 'Mediaset'},
#  {'name': 'Mindray Medical International'},
#  {'name': 'Baidu'},
#  {'name': 'Dentsu'},
#  {'name': 'Tata Communications'},
#  {'name': 'Atmel'},
#  {'name': 'Acxiom'},
#  {'name': 'Acxiom'},
#  {'name': 'SRA International'},
#  {'name': "Moody's"},
#  {'name': 'ManTech'},
#  {'name': 'Adobe Systems'},
#  {'name': 'Broadcom'}]

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
list(db['companies'].find({'$and':[{'founded_year':{'$gte':2000}}, {'founded_year':{'$lte':2005}}]},projection={'founded_year':1,'name':1,'_id':0}))
# Out:
# [{'name': 'Wetpaint', 'founded_year': 2005},
#  {'name': 'Zoho', 'founded_year': 2005},
#  {'name': 'Digg', 'founded_year': 2004},
#  {'name': 'Facebook', 'founded_year': 2004},
#  {'name': 'Omnidrive', 'founded_year': 2005},
#  {'name': 'StumbleUpon', 'founded_year': 2002},
#  {'name': 'Gizmoz', 'founded_year': 2003},
#  {'name': 'Helio', 'founded_year': 2005},
#  {'name': 'Plaxo', 'founded_year': 2002},
#  {'name': 'Technorati', 'founded_year': 2002},
#  {'name': 'AddThis', 'founded_year': 2004},
#  {'name': 'Veoh', 'founded_year': 2004},
#  {'name': 'Jingle Networks', 'founded_year': 2005},
#  {'name': 'Meetup', 'founded_year': 2002},
#  {'name': 'LifeLock', 'founded_year': 2005},
#  {'name': 'Wesabe', 'founded_year': 2005},
#  {'name': 'Jangl SMS', 'founded_year': 2005},
#  {'name': 'SmugMug', 'founded_year': 2002},
#  {'name': 'Jajah', 'founded_year': 2005},
#  {'name': 'Skype', 'founded_year': 2003},
#  {'name': 'YouTube', 'founded_year': 2005},
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
list(db['companies'].find({'$and':[{'founded_year':{'$lt':2010}},{'ipo.valuation_amount':{'$gt':1000000}}]},projection={'name':1,'_id':0}))
# Out:
# [{'name': 'Facebook'},
#  {'name': 'Twitter'},
#  {'name': 'Yelp'},
#  {'name': 'LinkedIn'},
#  {'name': 'Amazon'},
#  {'name': 'Brightcove'},
#  {'name': 'KIT digital'},
#  {'name': 'Nielsen'},
#  {'name': 'OpenTable'},
#  {'name': 'ChannelAdvisor'},
#  {'name': 'Jive Software'},
#  {'name': 'Zillow'},
#  {'name': 'Wix'},
#  {'name': 'Vringo'},
#  {'name': 'Shutterfly'},
#  {'name': 'TripAdvisor'},
#  {'name': 'Salesforce'},
#  {'name': 'HomeAway'},
#  {'name': 'QuinStreet'},
#  {'name': 'Rackspace'},
#  {'name': 'BMC Software'},
#  {'name': 'Higher One'},
#  {'name': 'Infoblox'},
#  {'name': 'Tencent'},
#  {'name': 'Marketo'},
#  {'name': 'Baidu'},
#  {'name': 'Geeknet'},
#  {'name': 'Opsware'},
#  {'name': 'Telenav'},
#  {'name': 'Rally Software'},
#  {'name': 'BrightSource Energy'},
#  {'name': 'Mixi'},
#  {'name': 'QlikTech'},
#  {'name': 'Pironet'},
#  {'name': 'Inuvo'},
#  {'name': 'Chegg'},
#  {'name': 'Pironet'},
#  {'name': 'Inuvo'},
#  {'name': 'Chegg'},
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
list(db['companies'].find(filter={'$and':[{'founded_year':{'$gt':2005}},{'number_of_employees':{'$lt':1000}}]},sort=[('number_of_employees',1)],limit=10,projection={'name':1,'founded_year':1,'_id':0,'number_of_employees':1}))
# Out:
# [{'name': 'Joost', 'number_of_employees': 0, 'founded_year': 2006},
#  {'name': 'CastTV', 'number_of_employees': 0, 'founded_year': 2006},
#  {'name': 'EQO', 'number_of_employees': 0, 'founded_year': 2006},
#  {'name': 'Mashery', 'number_of_employees': 0, 'founded_year': 2006},
#  {'name': 'coRank', 'number_of_employees': 0, 'founded_year': 2007},
#  {'name': 'Go2Web20', 'number_of_employees': 0, 'founded_year': 2006},
#  {'name': 'Cofoundr', 'number_of_employees': 0, 'founded_year': 2007},
#  {'name': 'Gumiyo', 'number_of_employees': 0, 'founded_year': 2006},
#  {'name': 'Checkster', 'number_of_employees': 0, 'founded_year': 2006},
#  {'name': 'Sportingo', 'number_of_employees': 0, 'founded_year': 2006}]

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
list(db['companies'].find(filter={'partners':{'$exists':False}}))
# Out:
# []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
list(db['companies'].find(filter={'category_code':{'$eq':None}},projection={'name':1,'_id':0}))
# Out:
# [{'name': 'Collective'},
#  {'name': 'Snimmer'},
#  {'name': 'KoolIM'},
#  {'name': 'Level9 Media'},
#  {'name': 'VidKing'},
#  {'name': 'Drigg'},
#  {'name': 'SpaceTime'},
#  {'name': 'Touch Clarity'},
#  {'name': 'MMDAYS'},
#  {'name': 'Inside Group'},
#  {'name': 'Repeater Store'},
#  {'name': 'Tapesh'},
#  {'name': 'iPersians'},
#  {'name': 'NewPersia'},
#  {'name': 'Pyra Labs'},
#  {'name': 'Feedmap'},
#  {'name': 'NuvoMedia'},
#  {'name': 'Intwine'},
#  {'name': 'The Weinstein Company'},
#  {'name': 'ExecuNet'},
#  {'name': 'A1Vacations'},
#  {'name': 'TripHomes'},
#  {'name': 'Picturehouse'},
#  {'name': 'Covalent Technologies'},
#  {'name': 'Epic Trip'},
#  {'name': 'Telepost'},
#  {'name': 'Fidelity'},
#  {'name': 'Quirk'},
#  {'name': 'Skyrove'},
#  {'name': 'Leechblock'},
#  {'name': 'My Success Gateway'},
#  {'name': 'RealNames'},
#  {'name': 'The Easynet Group'},
#  {'name': 'NetNames'},
#  {'name': 'Sniperoo'},
#  {'name': 'JD Project'},
#  {'name': 'ABC News'},
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
list(db['companies'].find(filter={'category_code':{'$eq':None}},projection={'name':1,'_id':0}))
# Out:
# [{'name': 'Collective'},
#  {'name': 'Snimmer'},
#  {'name': 'KoolIM'},
#  {'name': 'Level9 Media'},
#  {'name': 'VidKing'},
#  {'name': 'Drigg'},
#  {'name': 'SpaceTime'},
#  {'name': 'Touch Clarity'},
#  {'name': 'MMDAYS'},
#  {'name': 'Inside Group'},
#  {'name': 'Repeater Store'},
#  {'name': 'Tapesh'},
#  {'name': 'iPersians'},
#  {'name': 'NewPersia'},
#  {'name': 'Pyra Labs'},
#  {'name': 'Feedmap'},
#  {'name': 'NuvoMedia'},
#  {'name': 'Intwine'},
#  {'name': 'The Weinstein Company'},
#  {'name': 'ExecuNet'},
#  {'name': 'A1Vacations'},
#  {'name': 'TripHomes'},
#  {'name': 'Picturehouse'},
#  {'name': 'Covalent Technologies'},
#  {'name': 'Epic Trip'},
#  {'name': 'Telepost'},
#  {'name': 'Fidelity'},
#  {'name': 'Quirk'},
#  {'name': 'Skyrove'},
#  {'name': 'Leechblock'},
#  {'name': 'My Success Gateway'},
#  {'name': 'RealNames'},
#  {'name': 'The Easynet Group'},
#  {'name': 'NetNames'},
#  {'name': 'Sniperoo'},
#  {'name': 'JD Project'},
#  {'name': 'ABC News'},
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
list(db['Companies'].find({'ipo.valuation_amount':{'$ne':None}},sort=[('ipo.valuation_amount',-1)],projection={'name':1,'ipo.valuation_amount':1,'_id':0}))
# Out:
# []

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
 list(db['companies'].find(sort=[('number_of_employees',-1)],limit=10,projection={'name':1,'_id':0,'number_of_employees':1}))
# Out:
# [{'name': 'Siemens', 'number_of_employees': 405000},
#  {'name': 'IBM', 'number_of_employees': 388000},
#  {'name': 'Toyota', 'number_of_employees': 320000},
#  {'name': 'PayPal', 'number_of_employees': 300000},
#  {'name': 'Nippon Telegraph and Telephone Corporation',
#   'number_of_employees': 227000},
#  {'name': 'Samsung Electronics', 'number_of_employees': 221726},
#  {'name': 'Accenture', 'number_of_employees': 205000},
#  {'name': 'Tata Consultancy Services', 'number_of_employees': 200300},
#  {'name': 'Flextronics International', 'number_of_employees': 200000},
#  {'name': 'Safeway', 'number_of_employees': 186000}]

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
list(db['companies'].find({'founded_month':{'$gt':6}},limit=1000,projection={'name':1,'_id':0,'founded_month':1}))
# Out:
# [{'name': 'Wetpaint', 'founded_month': 10},
#  {'name': 'Zoho', 'founded_month': 9},
#  {'name': 'Digg', 'founded_month': 10},
#  {'name': 'Omnidrive', 'founded_month': 11},
#  {'name': 'eBay', 'founded_month': 9},
#  {'name': 'Joost', 'founded_month': 10},
#  {'name': 'Plaxo', 'founded_month': 11},
#  {'name': 'Powerset', 'founded_month': 10},
#  {'name': 'Kyte', 'founded_month': 12},
#  {'name': 'Thoof', 'founded_month': 12},
#  {'name': 'Jingle Networks', 'founded_month': 9},
#  {'name': 'LifeLock', 'founded_month': 8},
#  {'name': 'Wesabe', 'founded_month': 12},
#  {'name': 'SmugMug', 'founded_month': 11},
#  {'name': 'Google', 'founded_month': 9},
#  {'name': 'Skype', 'founded_month': 8},
#  {'name': 'Pando Networks', 'founded_month': 7},
#  {'name': 'Ikan', 'founded_month': 12},
#  {'name': 'delicious', 'founded_month': 9},
#  {'name': 'AllPeers', 'founded_month': 8},
#  {'name': 'Wize', 'founded_month': 8},
#  {'name': 'SellABand', 'founded_month': 8},
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
 list(db['companies'].find({'$and':[{'founded_year':{'$gt':2000}},{'acquisition.price_amount':{'$gt':10000000}}]},projection={'name':1,'_id':0,'founded_year':1,'acquisition.price_amount':1}))
# Out:
# [{'name': 'Wetpaint',
#   'founded_year': 2005,
#   'acquisition': {'price_amount': 30000000}},
#  {'name': 'StumbleUpon',
#   'founded_year': 2002,
#   'acquisition': {'price_amount': 29000000}},
#  {'name': 'Helio',
#   'founded_year': 2005,
#   'acquisition': {'price_amount': 39000000}},
#  {'name': 'Plaxo',
#   'founded_year': 2002,
#   'acquisition': {'price_amount': 150000000}},
#  {'name': 'Powerset',
#   'founded_year': 2006,
#   'acquisition': {'price_amount': 100000000}},
#  {'name': 'Jingle Networks',
#   'founded_year': 2005,
#   'acquisition': {'price_amount': 62500000}},
#  {'name': 'Jajah',
#   'founded_year': 2005,
#   'acquisition': {'price_amount': 207000000}},
#  {'name': 'Skype',
#   'founded_year': 2003,
#   'acquisition': {'price_amount': 2600000000}},
#  {'name': 'YouTube',
#   'founded_year': 2005,
#   'acquisition': {'price_amount': 1650000000}},
#  {'name': 'GrandCentral',
#   'founded_year': 2006,
#   'acquisition': {'price_amount': 60000000}},
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
 list(db['companies'].find({'acquisition.acquired_year':{'$gt':2015}},sort=[('acquisition.price_amount',-1)],projection={'name':1,'_id':0,'acquisition':1}))
# Out:
# []

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
list(db['companies'].find(sort=[('founded_year',-1)],limit=20,projection={'name':1,'_id':0,'founded_year':1}))
# Out:
# [{'name': 'Fixya', 'founded_year': 2013},
#  {'name': 'Wamba', 'founded_year': 2013},
#  {'name': 'Advaliant', 'founded_year': 2013},
#  {'name': 'Fluc', 'founded_year': 2013},
#  {'name': 'iBazar', 'founded_year': 2013},
#  {'name': 'Gimigo', 'founded_year': 2013},
#  {'name': 'SEOGroup', 'founded_year': 2013},
#  {'name': 'Clowdy', 'founded_year': 2013},
#  {'name': 'WhosCall', 'founded_year': 2013},
#  {'name': 'Pikk', 'founded_year': 2013},
#  {'name': 'Tongxue', 'founded_year': 2013},
#  {'name': 'Shopseen', 'founded_year': 2013},
#  {'name': 'VistaGen Therapeutics', 'founded_year': 2013},
#  {'name': 'PeekYou', 'founded_year': 2012},
#  {'name': 'headr', 'founded_year': 2012},
#  {'name': 'Pinger', 'founded_year': 2012},
#  {'name': 'Widgetbox', 'founded_year': 2012},
#  {'name': 'Mobiluck', 'founded_year': 2012},
#  {'name': 'Skydeck', 'founded_year': 2012},
#  {'name': 'Simplicant', 'founded_year': 2012}]

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
list(db['companies'].find({'founded_day':{'$lte':7}},sort=[('acquisition.price_amount',-1)],limit=10,projection={'name':1,'_id':0,'founded_day':1}))
# Out:
# [{'name': 'Netscape', 'founded_day': 4},
#  {'name': 'PayPal', 'founded_day': 1},
#  {'name': 'Zappos', 'founded_day': 1},
#  {'name': 'Alibaba', 'founded_day': 1},
#  {'name': 'Postini', 'founded_day': 2},
#  {'name': 'Danger', 'founded_day': 1},
#  {'name': 'Clearwell Systems', 'founded_day': 6},
#  {'name': 'PrimeSense', 'founded_day': 1},
#  {'name': 'Amobee', 'founded_day': 1},
#  {'name': 'BlueLithium', 'founded_day': 1}]

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
list(db['companies'].find({'$and':[{'category_code':{'$eq':'web'}},{'number_of_employees':{'$gt':4000}}]},sort=[('number_of_employees',1)],projection={'name':1,'_id':0,'number_of_employees':1,'category_code':1}))
# Out:
# [{'name': 'Expedia', 'category_code': 'web', 'number_of_employees': 4400},
#  {'name': 'AOL', 'category_code': 'web', 'number_of_employees': 8000},
#  {'name': 'Webkinz', 'category_code': 'web', 'number_of_employees': 8657},
#  {'name': 'Rakuten', 'category_code': 'web', 'number_of_employees': 10000},
#  {'name': 'Los Angeles Times Media Group',
#   'category_code': 'web',
#   'number_of_employees': 10000},
#  {'name': 'Groupon', 'category_code': 'web', 'number_of_employees': 10000},
#  {'name': 'Yahoo!', 'category_code': 'web', 'number_of_employees': 13600},
#  {'name': 'eBay', 'category_code': 'web', 'number_of_employees': 15000},
#  {'name': 'Experian', 'category_code': 'web', 'number_of_employees': 15500}]

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
list(db['companies'].find({'$and':[{"acquisition.price_amount":{'$gt':10000000}},{"acquisition.price_currency_code":{'$eq':'EUR'}}]},projection={'name':1,'_id':0,"acquisition.price_currency_code":1,"acquisition.price_amount":1}))
# Out:
# [{'name': 'ZYB',
#   'acquisition': {'price_amount': 31500000, 'price_currency_code': 'EUR'}},
#  {'name': 'Apertio',
#   'acquisition': {'price_amount': 140000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Greenfield Online',
#   'acquisition': {'price_amount': 40000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Webedia',
#   'acquisition': {'price_amount': 70000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Wayfinder',
#   'acquisition': {'price_amount': 24000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Tuenti Technologies',
#   'acquisition': {'price_amount': 70000000, 'price_currency_code': 'EUR'}},
#  {'name': 'BioMed Central',
#   'acquisition': {'price_amount': 43400000, 'price_currency_code': 'EUR'}}]

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
list(db['companies'].find({"acquisition.acquired_month":{'$lte':3}},limit=10,projection={'name':1,'_id':0,'acquisition':1}))
# Out:
# [{'name': 'Kyte',
#   'acquisition': {'price_amount': None,
#    'price_currency_code': 'USD',
#    'term_code': None,
#    'source_url': 'http://techcrunch.com/2011/01/31/exclusive-kit-digital-acquires-kickapps-kewego-and-kyte-for-77-2-million/',
#    'source_description': 'KIT digital Acquires KickApps, Kewego AND Kyte For $77.2 Million',
#    'acquired_year': 2011,
#    'acquired_month': 1,
#    'acquired_day': 31,
#    'acquiring_company': {'name': 'KIT digital', 'permalink': 'kit-digital'}}},
#  {'name': 'NetRatings',
#   'acquisition': {'price_amount': 327000000,
#    'price_currency_code': 'USD',
#    'term_code': 'cash',
#    'source_url': 'http://login.vnuemedia.com/hr/login/login_subscribe.jsp?id=0oqDem1gYIfIclz9i2%2Ffqj5NxCp2AC5DPbVnyT2da8GyV2mXjasabE128n69OrmcAh52%2FGE3pSG%2F%0AEKRYD9vh9EhrJrxukmUzh532fSMTZXL42gwPB80UWVtF1NwJ5UZSM%2BCkLU1mpYBoHFgiH%2Fi0f6Ax%0A9yMIVxt47t%2BHamhEQ0nkOEK24L',
#    'source_description': 'Nielsen buys rest of NetRatings',
# ...

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
 list(db['companies'].find({'$and':[{'founded_year':{'$gte':2000}},{'founded_year':{'$lte':2010}},{'acquisition':{'$eq':None}}]},projection={'name':1,'_id':0,'founded_year':1}))
# Out:
# [{'name': 'Zoho', 'founded_year': 2005},
#  {'name': 'Facebook', 'founded_year': 2004},
#  {'name': 'Omnidrive', 'founded_year': 2005},
#  {'name': 'Twitter', 'founded_year': 2006},
#  {'name': 'Scribd', 'founded_year': 2007},
#  {'name': 'Slacker', 'founded_year': 2006},
#  {'name': 'MeetMoi', 'founded_year': 2007},
#  {'name': 'Babelgum', 'founded_year': 2007},
#  {'name': 'Technorati', 'founded_year': 2002},
#  {'name': 'AddThis', 'founded_year': 2004},
#  {'name': 'OpenX', 'founded_year': 2008},
#  {'name': 'Mahalo', 'founded_year': 2007},
#  {'name': 'Sparter', 'founded_year': 2007},
#  {'name': 'Thoof', 'founded_year': 2006},
#  {'name': 'Meetup', 'founded_year': 2002},
#  {'name': 'LifeLock', 'founded_year': 2005},
#  {'name': 'Wesabe', 'founded_year': 2005},
#  {'name': 'Jangl SMS', 'founded_year': 2005},
#  {'name': 'SmugMug', 'founded_year': 2002},
#  {'name': 'Prosper', 'founded_year': 2006},
#  {'name': 'Stickam', 'founded_year': 2006},
# ...
