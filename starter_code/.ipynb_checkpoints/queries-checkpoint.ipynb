# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
import pandas as pd
client=MongoClient("mongodb://localhost:27017/")
db=client.db_companies
collection_companies = db.companies

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %% [markdown]
# From Mongo Compass
# Filter: {name: 'Babelgum'}
# Project: {name: 1}
# Sort
# Skip
# Limit

# %%
a = pd.DataFrame(collection_companies.find({"name": "Babelgum"}, {"name": 1, "_id": 0}))
a
# Out:
#        name
# 0  Babelgum

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %% [markdown]
# From Mongo Compass
# Filter: {number_of_employees: {$gt: 5000} }
# Project:
# Sort: {number_of_employees: -1}
# Skip:
# Limit: 20

# %%
b = pd.DataFrame(collection_companies.find({"number_of_employees": {"$gt": 5000} }).sort("number_of_employees", -1).limit(20))
b
# Out:
#                          _id                                        name  \
# 0   52cdef7d4bab8bd67529941a                                     Siemens
# 1   52cdef7c4bab8bd67529856a                                         IBM
# 2   52cdef7d4bab8bd675299d33                                      Toyota
# 3   52cdef7c4bab8bd675297e89                                      PayPal
# 4   52cdef7e4bab8bd67529b0fe  Nippon Telegraph and Telephone Corporation
# 5   52cdef7d4bab8bd675298aa4                         Samsung Electronics
# 6   52cdef7d4bab8bd675298b99                                   Accenture
# 7   52cdef7e4bab8bd67529a657                   Tata Consultancy Services
# 8   52cdef7e4bab8bd67529aa51                   Flextronics International
# 9   52cdef7d4bab8bd675299156                                     Safeway
# 10  52cdef7c4bab8bd675297e6f                                        Sony
# 11  52cdef7c4bab8bd675298517                                          LG
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %% [markdown]
# From Mongo Compass
# Filter: {founded_year: {$gte: 2000, $lte: 2005}}
# Project: {name: 1, founded_year: 1}
# Sort:
# Skip:
# Limit:

# %%
c = pd.DataFrame(collection_companies.find({"founded_year": {"$gt": 2000, "$lte": 2005} }, {"_id":0, "name":1, "founded_year":1}))
c
# Out:
#                          name  founded_year
# 0                    Wetpaint          2005
# 1                        Zoho          2005
# 2                   Omnidrive          2005
# 3                      Gizmoz          2003
# 4                       Helio          2005
# ...                       ...           ...
# 3208           Cameron Health          2001
# 3209  Celestial Semiconductor          2004
# 3210           Axon Solutions          2004
# 3211                  Intergy          2003
# 3212               AfterLogic          2002
#
# [3213 rows x 2 columns]

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %% [markdown]
# From Mongo Compass
# Filter: {$and: [{"ipo.valuation_amount": {$gt: 100000000}}, {founded_year: {$lt: 2010}}]}
# Project: {name: 1, ipo: 1}
# Sort:
# Skip:
# Limit:

# %%
d = pd.DataFrame(
    collection_companies.find({'$and': [{"ipo.valuation_amount": {'$gt': 100000000}}, {'founded_year': {'$lt': 2010}}]}, {'name': 1, 'ipo': 1, '_id': 0}))
d
# Out:
#                     name                                                ipo
# 0                Twitter  {'valuation_amount': 18100000000, 'valuation_c...
# 1               Facebook  {'valuation_amount': 104000000000, 'valuation_...
# 2                   Yelp  {'valuation_amount': 1300000000, 'valuation_cu...
# 3               LinkedIn  {'valuation_amount': 9310000000, 'valuation_cu...
# 4             Brightcove  {'valuation_amount': 290000000, 'valuation_cur...
# 5                 Amazon  {'valuation_amount': 100000000000, 'valuation_...
# 6            KIT digital  {'valuation_amount': 235000000, 'valuation_cur...
# 7                Nielsen  {'valuation_amount': 1600000000, 'valuation_cu...
# 8              OpenTable  {'valuation_amount': 1050000000, 'valuation_cu...
# 9         ChannelAdvisor  {'valuation_amount': 287000000, 'valuation_cur...
# 10         Jive Software  {'valuation_amount': 1000000000, 'valuation_cu...
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %% [markdown]
# From Mongo Compass
# Filter: {$and: [{"number_of_employees": {$lt: 1000}}, {founded_year: {$lt: 2005}}]}
# Project:
# Sort: {number_of_employees: -1}
# Skip:
# Limit: 10

# %%
e = pd.DataFrame(
    collection_companies.find({'$and': [{"number_of_employees": {'$lt': 1000}}, {'founded_year': {'$lt': 2005}}]}).sort("number_of_employees", -1).limit(10))
e
# Out:
#                         _id                             name  \
# 0  52cdef7d4bab8bd675298933             Infinera Corporation
# 1  52cdef7e4bab8bd67529ac95  NorthPoint Communications Group
# 2  52cdef7f4bab8bd67529be17                     888 Holdings
# 3  52cdef7c4bab8bd6752986a2               Forrester Research
# 4  52cdef7e4bab8bd67529b21b                       Webmetrics
# 5  52cdef7e4bab8bd67529af6d                        SonicWALL
# 6  52cdef7e4bab8bd67529b3bd             Cornerstone OnDemand
# 7  52cdef7c4bab8bd675297ff0                          Mozilla
# 8  52cdef7c4bab8bd6752985c5                            Cvent
# 9  52cdef7c4bab8bd675297efd                         ZoomInfo
#
#                          permalink  \
# 0                         infinera
# 1  northpoint-communications-group
# 2                     888-holdings
# 3               forrester-research
# 4                       webmetrics
# 5                        sonicwall
# 6             cornerstone-ondemand
# ...

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %% [markdown]
# From Mongo Compass
# Filter: {partners: {$exists: false}}
# Project:
# Sort:
# Skip:
# Limit:

# %%
f = pd.DataFrame(collection_companies.find({'partners': {'$exists': False}}))
f
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %% [markdown]
# From Mongo Compass
# Filter: {category_code: {$eq: null}}
# Project:
# Sort:
# Skip:
# Limit:

# %%
g = pd.DataFrame(collection_companies.find({'category_code': {'$eq': None}}))
g
# Out:
#                            _id          name     permalink  \
# 0     52cdef7c4bab8bd6752980f6    Collective    collective
# 1     52cdef7c4bab8bd675298225       Snimmer       snimmer
# 2     52cdef7c4bab8bd675298226        KoolIM        koolim
# 3     52cdef7c4bab8bd675298262       VidKing       vidking
# 4     52cdef7c4bab8bd675298261  Level9 Media  level9-media
# ...                        ...           ...           ...
# 2746  52cdef7f4bab8bd67529c6c8        Nellix        nellix
# 2747  52cdef7f4bab8bd67529c6de      Cantimer      cantimer
# 2748  52cdef7f4bab8bd67529c6e9      Coloroot      coloroot
# 2749  52cdef7f4bab8bd67529c6e8  cruisecritic  cruisecritic
# 2750  52cdef7f4bab8bd67529c6f4      Geekdive      geekdive
#
#                                       crunchbase_url             homepage_url  \
# 0       http://www.crunchbase.com/company/collective                     None
# 1          http://www.crunchbase.com/company/snimmer                     None
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %% [markdown]
# From Mongo Compass
# Filter: {number_of_employees: {$gte: 100, $lt: 1000}}
# Project: {name: 1, number_of_employees: 1}
# Sort:
# Skip:
# Limit:

# %%
h = pd.DataFrame(collection_companies.find({'number_of_employees': {'$gte': 100, '$lt': 1000}}, {"_id":0, "name":1, "number_of_employees":1}))
h
# Out:
#                       name  number_of_employees
# 0                AdventNet                  600
# 1                  AddThis                  120
# 2                    OpenX                  305
# 3                 LifeLock                  644
# 4                    Jajah                  110
# ..                     ...                  ...
# 912               NextLabs                  100
# 913  UOL (Universo Online)                  500
# 914      OfficialVirtualDJ                  102
# 915                   QSGI                  164
# 916          Willdan Group                  385
#
# [917 rows x 2 columns]

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %% [markdown]
# From Mongo Compass
# Filter: {ipo: {$not: {$eq: null}}}
# Project:
# Sort: {"ipo.valuation_amount": -1}
# Skip:
# Limit:

# %%
i = pd.DataFrame(collection_companies.find({'ipo': {'$not': {'$eq': None}}}).sort('ipo.valuation_amount', -1))
i
# Out:
#                           _id                name           permalink  \
# 0    52cdef7e4bab8bd67529a8b4                GREE                gree
# 1    52cdef7c4bab8bd675297d8e            Facebook            facebook
# 2    52cdef7c4bab8bd675297e7a              Amazon              amazon
# 3    52cdef7c4bab8bd675297d94             Twitter             twitter
# 4    52cdef7d4bab8bd675299d5d             Groupon             groupon
# ..                        ...                 ...                 ...
# 385  52cdef7f4bab8bd67529c5fe           InfoLogix           infologix
# 386  52cdef7f4bab8bd67529c60b  Oxford Instruments  oxford-instruments
# 387  52cdef7f4bab8bd67529c609                 INX                 inx
# 388  52cdef7f4bab8bd67529c61b  Zebra Technologies  zebra-technologies
# 389  52cdef7f4bab8bd67529c637              Lenovo              lenovo
#
#                                         crunchbase_url  \
# 0               http://www.crunchbase.com/company/gree
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %% [markdown]
# From Mongo Compass
# Filter:
# Project:
# Sort: {"number_of_employees": -1}
# Skip:
# Limit: 10

# %%
j = pd.DataFrame(collection_companies.find({}).sort('number_of_employees', -1).limit(10))
j
# Out:
#                         _id                                        name  \
# 0  52cdef7d4bab8bd67529941a                                     Siemens
# 1  52cdef7c4bab8bd67529856a                                         IBM
# 2  52cdef7d4bab8bd675299d33                                      Toyota
# 3  52cdef7c4bab8bd675297e89                                      PayPal
# 4  52cdef7e4bab8bd67529b0fe  Nippon Telegraph and Telephone Corporation
# 5  52cdef7d4bab8bd675298aa4                         Samsung Electronics
# 6  52cdef7d4bab8bd675298b99                                   Accenture
# 7  52cdef7e4bab8bd67529a657                   Tata Consultancy Services
# 8  52cdef7e4bab8bd67529aa51                   Flextronics International
# 9  52cdef7d4bab8bd675299156                                     Safeway
#
#                                     permalink  \
# 0                                     siemens
# 1                                         ibm
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %% [markdown]
# From Mongo Compass
# Filter: {founded_month: {$gte: 7}}
# Project:
# Sort:
# Skip:
# Limit: 1000

# %%
k = pd.DataFrame(collection_companies.find({'founded_month': {'$gte': 7}}).limit(1000))
k
# Out:
#                           _id          name     permalink  \
# 0    52cdef7c4bab8bd675297d8a      Wetpaint          abc2
# 1    52cdef7c4bab8bd675297d8c          Zoho          abc4
# 2    52cdef7c4bab8bd675297d8f     Omnidrive     omnidrive
# 3    52cdef7c4bab8bd675297d9d         Joost         joost
# 4    52cdef7c4bab8bd675297d8d          Digg          digg
# ..                        ...           ...           ...
# 995  52cdef7d4bab8bd675299145      LingusTV      lingustv
# 996  52cdef7d4bab8bd675299148  AccountMaven  accountmaven
# 997  52cdef7d4bab8bd67529914f      Chapatiz      chapatiz
# 998  52cdef7d4bab8bd67529915e       YOOWALK       yoowalk
# 999  52cdef7d4bab8bd675299170   Data Domain   data-domain
#
#                                      crunchbase_url  \
# 0        http://www.crunchbase.com/company/wetpaint
# 1            http://www.crunchbase.com/company/zoho
# 2       http://www.crunchbase.com/company/omnidrive
# 3           http://www.crunchbase.com/company/joost
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %% [markdown]
# From Mongo Compass
# Filter: {$expr: {$gt: ['$deadpooled_year', {$add: ['$founded_year',3]}]}}
# Project:
# Sort:
# Skip:
# Limit:

# %%
l = pd.DataFrame(collection_companies.find({'$expr': {'$gt': ['$deadpooled_year', {'$add': ['$founded_year',3]}]}}))
l
# Out:
#                           _id            name       permalink  \
# 0    52cdef7c4bab8bd675297da0        Babelgum        babelgum
# 1    52cdef7c4bab8bd675297dae           Thoof           thoof
# 2    52cdef7c4bab8bd675297db3         Mercora         mercora
# 3    52cdef7c4bab8bd675297db6          Wesabe          wesabe
# 4    52cdef7c4bab8bd675297dbe         Stickam         stickam
# ..                        ...             ...             ...
# 650  52cdef7f4bab8bd67529c579        TrueSpan        truespan
# 651  52cdef7f4bab8bd67529c590      Eyetronics      eyetronics
# 652  52cdef7f4bab8bd67529c5aa  Nethra Imaging  nethra-imaging
# 653  52cdef7f4bab8bd67529c68b         Prolify         prolify
# 654  52cdef7f4bab8bd67529c6ec       Embedster       embedster
#
#                                        crunchbase_url  \
# 0          http://www.crunchbase.com/company/babelgum
# 1             http://www.crunchbase.com/company/thoof
# 2           http://www.crunchbase.com/company/mercora
# ...

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
From Mongo Compass
Filter: {$and: [{founded_year: {$lt: 2000}}, {"acquisition.price_amount": {$gt: 10000000}}]}
Project:
Sort: 
Skip:
Limit:

# %%
m = pd.DataFrame(collection_companies.find({'$and': [{'founded_year': {'$lt': 2000}}, {"acquisition.price_amount": {'$gt': 10000000}}]}))
m
# Out:
#                           _id                            name  \
# 0    52cdef7c4bab8bd675297d90                         Postini
# 1    52cdef7c4bab8bd675297deb                        SideStep
# 2    52cdef7c4bab8bd675297e2c                      Recipezaar
# 3    52cdef7c4bab8bd675297e89                          PayPal
# 4    52cdef7c4bab8bd675297e97                        Snapfish
# ..                        ...                             ...
# 200  52cdef7f4bab8bd67529c6a2                         Savvion
# 201  52cdef7f4bab8bd67529c6ac            Inventa Technologies
# 202  52cdef7f4bab8bd67529c6bb             Universal Microwave
# 203  52cdef7f4bab8bd67529c6c3     Advanced Control Components
# 204  52cdef7f4bab8bd67529c6f2  Contemporary Computer Services
#
#                           permalink  \
# 0                           postini
# 1                          sidestep
# 2                        recipezaar
# 3                            paypal
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %% [markdown]
# From Mongo Compass
# Filter: {"acquisition.acquired_year": {$gt: 2015}}
# Project: {name: 1, acquisition: 1}
# Sort: {"acquisition.price_amount": -1}
# Skip:
# Limit:

# %%
n = pd.DataFrame(collection_companies.find({'acquisition.acquired_year': {'$gt': 2015}}, {'name': 1, 'acquisition': 1, "_id": 0}).sort('acquisition.price_amount', -1))
n
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %% [markdown]
# From Mongo Compass
# Filter:
# Project: {name: 1, founded_year: 1, _id: 0}
# Sort: {founded_year: -1}
# Skip:
# Limit:

# %%
n = pd.DataFrame(collection_companies.find({}, {'name': 1, 'founded_year': 1, "_id": 0}).sort('founded_year', -1))
n
# Out:
#                       name  founded_year
# 0                    Fixya        2013.0
# 1                    Wamba        2013.0
# 2                Advaliant        2013.0
# 3                     Fluc        2013.0
# 4                   iBazar        2013.0
# ...                    ...           ...
# 18796        Willdan Group           NaN
# 18797             Geekdive           NaN
# 18798            Embedster           NaN
# 18799  EnteGreat Solutions           NaN
# 18800          goBookmaker           NaN
#
# [18801 rows x 2 columns]

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %% [markdown]
# From Mongo Compass
# Filter: {founded_day: {$lte: 7}}
# Project:
# Sort: {"acquisition.price_amount": -1}
# Skip:
# Limit: 10

# %%
o = pd.DataFrame(collection_companies.find({'founded_day': {'$lte': 7}}).sort('acquisition.price_amount', -1).limit(10))
o
# Out:
#                         _id               name          permalink  \
# 0  52cdef7d4bab8bd6752989a1           Netscape           netscape
# 1  52cdef7c4bab8bd675297e89             PayPal             paypal
# 2  52cdef7c4bab8bd675297efe             Zappos             zappos
# 3  52cdef7c4bab8bd675297f0c            Alibaba            alibaba
# 4  52cdef7c4bab8bd675297d90            Postini            postini
# 5  52cdef7c4bab8bd67529831c             Danger             danger
# 6  52cdef7c4bab8bd675298651  Clearwell Systems  clearwell-systems
# 7  52cdef7d4bab8bd6752989b8         PrimeSense         primesense
# 8  52cdef7c4bab8bd675298207             Amobee             amobee
# 9  52cdef7c4bab8bd675298095             Vitrue             vitrue
#
#                                       crunchbase_url  \
# 0         http://www.crunchbase.com/company/netscape
# 1           http://www.crunchbase.com/company/paypal
# 2           http://www.crunchbase.com/company/zappos
# ...

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
From Mongo Compass
Filter: {$and: [{category_code: 'web'}, {number_of_employees: {$gt: 4000}}]}
Project: 
Sort: {number_of_employees: 1}
Skip:
Limit:

# %%
p = pd.DataFrame(collection_companies.find({'$and': [{'category_code': 'web'}, {'number_of_employees': {'$gt': 4000}}]}).sort('number_of_employees', 1))
p
# Out:
#                         _id                           name  \
# 0  52cdef7c4bab8bd67529822a                        Expedia
# 1  52cdef7c4bab8bd675297e96                            AOL
# 2  52cdef7c4bab8bd675297ea4                        Webkinz
# 3  52cdef7c4bab8bd675297fcb                        Rakuten
# 4  52cdef7c4bab8bd67529834c  Los Angeles Times Media Group
# 5  52cdef7d4bab8bd675299d5d                        Groupon
# 6  52cdef7c4bab8bd675297da3                         Yahoo!
# 7  52cdef7c4bab8bd675297d9b                           eBay
# 8  52cdef7c4bab8bd6752982a8                       Experian
#
#                        permalink  \
# 0                        expedia
# 1                            aol
# 2                        webkinz
# 3                        rakuten
# 4  los-angeles-times-media-group
# 5                        groupon
# 6                          yahoo
# 7                           ebay
# 8                       experian
#
# ...

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %% [markdown]
# From Mongo Compass
# Filter: {$and: [{"acquisition.price_amount": {$gt: 10000000}}, {"acquisition.price_currency_code": 'EUR'}]}
# Project:
# Sort:
# Skip:
# Limit:

# %%
q = pd.DataFrame(collection_companies.find({'$and': [{"acquisition.price_amount": {'$gt': 10000000}}, {"acquisition.price_currency_code": 'EUR'}]}))
q
# Out:
#                         _id                 name            permalink  \
# 0  52cdef7c4bab8bd675297f02                  ZYB                  zyb
# 1  52cdef7d4bab8bd675298bf3              Apertio              apertio
# 2  52cdef7d4bab8bd675298f47    Greenfield Online    greenfield-online
# 3  52cdef7e4bab8bd67529a536              Webedia              webedia
# 4  52cdef7e4bab8bd67529a729            Wayfinder            wayfinder
# 5  52cdef7e4bab8bd67529b747  Tuenti Technologies  tuenti-technologies
# 6  52cdef7f4bab8bd67529c0cf       BioMed Central       biomed-central
#
#                                       crunchbase_url  \
# 0              http://www.crunchbase.com/company/zyb
# 1          http://www.crunchbase.com/company/apertio
# 2  http://www.crunchbase.com/company/greenfield-o...
# 3          http://www.crunchbase.com/company/webedia
# 4        http://www.crunchbase.com/company/wayfinder
# 5  http://www.crunchbase.com/company/tuenti-techn...
# ...

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %% [markdown]
# From Mongo Compass
# Filter: {$and: [{"acquisition.price_amount": {$gt: 10000000}}, {"acquisition.price_currency_code": 'EUR'}]}
# Project: {_id: 0, name: 1, acquisition: 1}
# Sort:
# Skip:
# Limit: 10

# %%
r = pd.DataFrame(collection_companies.find({'$and': [{"acquisition.price_amount": {'$gt': 10000000}}, {"acquisition.price_currency_code": 'EUR'}]}, {'_id': 0, 'name': 1, 'acquisition': 1}).limit(10))
r
# Out:
#                   name                                        acquisition
# 0                  ZYB  {'price_amount': 31500000, 'price_currency_cod...
# 1              Apertio  {'price_amount': 140000000, 'price_currency_co...
# 2    Greenfield Online  {'price_amount': 40000000, 'price_currency_cod...
# 3              Webedia  {'price_amount': 70000000, 'price_currency_cod...
# 4            Wayfinder  {'price_amount': 24000000, 'price_currency_cod...
# 5  Tuenti Technologies  {'price_amount': 70000000, 'price_currency_cod...
# 6       BioMed Central  {'price_amount': 43400000, 'price_currency_cod...

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %% [markdown]
# From Mongo Compass
# Filter: {$and: [{founded_year: {$gte: 2000}}, {founded_year: {$lte: 2010}}, {"acquisition.acquired_year": {$gte: 2011}}]}
# Project:
# Sort:
# Skip:
# Limit:

# %%
s = pd.DataFrame(collection_companies.find({'$and': [{'founded_year': {'$gte': 2000}}, {'founded_year': {'$lte': 2010}}, {"acquisition.acquired_year": {'$gte': 2011}}]}))
s
# Out:
#                           _id                     name  \
# 0    52cdef7c4bab8bd675297d8a                 Wetpaint
# 1    52cdef7c4bab8bd675297d91                     Geni
# 2    52cdef7c4bab8bd675297d8d                     Digg
# 3    52cdef7c4bab8bd675297dab                     Kyte
# 4    52cdef7c4bab8bd675297daf          Jingle Networks
# ..                        ...                      ...
# 481  52cdef7f4bab8bd67529c691                     ALOT
# 482  52cdef7f4bab8bd67529c6b4               OptiMedica
# 483  52cdef7f4bab8bd67529c6c5          Luminus Devices
# 484  52cdef7f4bab8bd67529c6e2                MyChances
# 485  52cdef7f4bab8bd67529c6e0  Celestial Semiconductor
#
#                    permalink  \
# 0                       abc2
# 1                       geni
# 2                       digg
# 3                       kyte
# 4            jingle-networks
# ..                       ...
# 481                     alot
# 482               optimedica
# ...
