# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
import pandas as pd

# connection with mongo
client = MongoClient("mongodb+srv://admin:2593@cluster0.ebfrc.mongodb.net/<dbname>?retryWrites=true&w=majority")

# connection with database "db_companies"
db = client.db_companies

# companies collection
collection_companies = db.companies

# querying EVERYTHING
query = collection_companies.find()

# convert to pandas.DataFrame
df = pd.DataFrame(query)

# %%
collection_companies

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
pd.DataFrame(collection_companies.find({'name':'Babelgum'},{'_id':0,'name':1}))
# Out:
#        name
# 0  Babelgum

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
#En sort() -1 es descendente, 1 es ascendente
pd.DataFrame(collection_companies.find({'number_of_employees':{"$gt":5000}}).limit(20).sort("number_of_employees",1)).head(3)
# Out:
#                         _id                   name              permalink  \
# 0  52cdef7c4bab8bd675297e49               Nintendo               nintendo
# 1  52cdef7e4bab8bd67529ba2e  Hexaware Technologies  hexaware-technologies
# 2  52cdef7c4bab8bd675297d8e               Facebook               facebook
#
#                                       crunchbase_url             homepage_url  \
# 0         http://www.crunchbase.com/company/nintendo      http://nintendo.com
# 1  http://www.crunchbase.com/company/hexaware-tec...  http://www.hexaware.com
# 2         http://www.crunchbase.com/company/facebook      http://facebook.com
#
#                     blog_url                      blog_feed_url  \
# 0
# 1  http://blogs.hexaware.com     http://blogs.hexaware.com/feed
# 2   http://blog.facebook.com  http://blog.facebook.com/atom.php
#
#   twitter_username category_code  number_of_employees  ...  \
# 0  NintendoAmerica   games_video                 5080  ...
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
#Pones el $and y en seguida una lista de dicts con todas las condiciones a cumplir
pd.DataFrame(collection_companies.find({'$and':[{"founded_year":{"$gte":2000}},{"founded_year":{"$lte":2005}}]},{"_id":0,"name":1,"founded_year":1})).head(3)
# Out:
#        name  founded_year
# 0  Wetpaint          2005
# 1      Zoho          2005
# 2      Digg          2004

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
#Cuando es un campo dentro de otro se separan con un punto ej: "ipo.valuation_amount"
pd.DataFrame(collection_companies.find({'$and':[{"ipo.valuation_amount":{"$gt":100000000}},{"founded_year":{"$lt":2010}}]},{"_id":0,"name":1,"ipo":1})).head(3)
# Out:
#        name                                                ipo
# 0  Facebook  {'valuation_amount': 104000000000, 'valuation_...
# 1   Twitter  {'valuation_amount': 18100000000, 'valuation_c...
# 2      Yelp  {'valuation_amount': 1300000000, 'valuation_cu...

# %%
pd.json_normalize(collection_companies.find({'$and':[{"ipo.valuation_amount":{"$gt":100000000}},{"founded_year":{"$lt":2010}}]},{"_id":0,"name":1,"ipo":1}).sort("ipo.valuation_amount",-1)).head(3)
# Out:
#        name  ipo.valuation_amount ipo.valuation_currency_code  ipo.pub_year  \
# 0  Facebook          104000000000                         USD        2012.0
# 1    Amazon          100000000000                         USD        1997.0
# 2   Twitter           18100000000                         USD        2013.0
#
#    ipo.pub_month  ipo.pub_day ipo.stock_symbol
# 0            5.0         18.0        NASDAQ:FB
# 1            5.0          NaN      NASDAQ:AMZN
# 2           11.0          7.0        NYSE:TWTR

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
pd.DataFrame(collection_companies.find({'$and':[{"number_of_employees":{"$lt":1000}},{"founded_year":{"$lt":2005}}]}).sort('number_of_employees').limit(10)).head(3)
# Out:
#                         _id                   name              permalink  \
# 0  52cdef7c4bab8bd675297d93  Fox Interactive Media  fox-interactive-media
# 1  52cdef7c4bab8bd675297dbc                  Skype                  skype
# 2  52cdef7c4bab8bd675297e12           Ticketmaster           ticketmaster
#
#                                       crunchbase_url  \
# 0  http://www.crunchbase.com/company/fox-interact...
# 1            http://www.crunchbase.com/company/skype
# 2     http://www.crunchbase.com/company/ticketmaster
#
#                   homepage_url                blog_url  \
# 0      http://www.newscorp.com
# 1         http://www.skype.com  http://blogs.skype.com
# 2  http://www.ticketmaster.com
#
#                               blog_feed_url twitter_username category_code  \
# 0                                                 twitterapi           web
# 1  http://feeds.feedburner.com/shareskypeen            skype      software
# ...

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
#{<'nombre campo'>:{$exists: <'false' o 'true'>}}
pd.DataFrame(collection_companies.find({'partners':{"$exists":"False"}})).head(3)
# Out:
#                         _id       name permalink  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint      abc2
# 1  52cdef7c4bab8bd675297d8b  AdventNet      abc3
# 2  52cdef7c4bab8bd675297d8c       Zoho      abc4
#
#                                 crunchbase_url             homepage_url  \
# 0   http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 1  http://www.crunchbase.com/company/adventnet     http://adventnet.com
# 2       http://www.crunchbase.com/company/zoho          http://zoho.com
#
#                       blog_url                     blog_feed_url  \
# 0  http://digitalquarters.net/  http://digitalquarters.net/feed/
# 1
# 2       http://blogs.zoho.com/        http://blogs.zoho.com/feed
#
#   twitter_username category_code  number_of_employees  ...  \
# 0  BachelrWetpaint           web                 47.0  ...
# 1     manageengine    enterprise                600.0  ...
# 2             zoho      software               1600.0  ...
#
# ...

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
#Para buscar null se usa None
pd.DataFrame(collection_companies.find({'category_code':None})).head(3)
# Out:
#                         _id        name   permalink  \
# 0  52cdef7c4bab8bd6752980f6  Collective  collective
# 1  52cdef7c4bab8bd675298225     Snimmer     snimmer
# 2  52cdef7c4bab8bd675298226      KoolIM      koolim
#
#                                  crunchbase_url homepage_url blog_url  \
# 0  http://www.crunchbase.com/company/collective         None     None
# 1     http://www.crunchbase.com/company/snimmer         None     None
# 2      http://www.crunchbase.com/company/koolim         None     None
#
#   blog_feed_url twitter_username category_code  number_of_employees  ...  \
# 0          None             None          None                  NaN  ...
# 1          None             None          None                  NaN  ...
# 2          None             None          None                  NaN  ...
#
#    investments  acquisition  acquisitions  offices  milestones   ipo  \
# 0           []         None            []       []          []  None
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
pd.DataFrame(collection_companies.find({'$and':[{"number_of_employees":{"$gte":100}},{"number_of_employees":{"$lt":1000}}]},{'_id':0,'name':1,'number_of_employees':1})).head(3)
# Out:
#         name  number_of_employees
# 0  AdventNet                  600
# 1    AddThis                  120
# 2      OpenX                  305

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
pd.DataFrame(collection_companies.find().sort("ipo.valuation_amount",-1).limit(10)).head(3)
# Out:
#                         _id      name permalink  \
# 0  52cdef7e4bab8bd67529a8b4      GREE      gree
# 1  52cdef7c4bab8bd675297d8e  Facebook  facebook
# 2  52cdef7c4bab8bd675297e7a    Amazon    amazon
#
#                                crunchbase_url              homepage_url  \
# 0      http://www.crunchbase.com/company/gree  http://www.gree-corp.com
# 1  http://www.crunchbase.com/company/facebook       http://facebook.com
# 2    http://www.crunchbase.com/company/amazon         http://amazon.com
#
#                    blog_url                      blog_feed_url  \
# 0
# 1  http://blog.facebook.com  http://blog.facebook.com/atom.php
# 2
#
#   twitter_username category_code  number_of_employees  ...  \
# 0        gree_corp   games_video                700.0  ...
# 1         facebook        social               5299.0  ...
# 2           amazon     ecommerce                  NaN  ...
#
#                                          investments  acquisition  \
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
pd.DataFrame(collection_companies.find().sort('number_of_employees',-1).limit(10))
# Out:
#                         _id                                        name  \
# 0  52cdef7d4bab8bd67529941a                                     Siemens
# 1  52cdef7c4bab8bd67529856a                                         IBM
# 2  52cdef7d4bab8bd675299d33                                      Toyota
# 3  52cdef7c4bab8bd675297e89                                      PayPal
# 4  52cdef7e4bab8bd67529b0fe  Nippon Telegraph and Telephone Corporation
# 5  52cdef7d4bab8bd675298aa4                         Samsung Electronics
# 6  52cdef7d4bab8bd675298b99                                   Accenture
# 7  52cdef7e4bab8bd67529a657                   Tata Consultancy Services
# 8  52cdef7e4bab8bd67529aa51                   Flextronics International
# 9  52cdef7d4bab8bd675299156                                     Safeway
#
#                                     permalink  \
# 0                                     siemens
# 1                                         ibm
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
pd.DataFrame(collection_companies.find({'$and':[{"founded_month":{"$gt":5}},{"founded_month":{"$lte":12}}]}).limit(1000)).head(3)
# Out:
#                         _id      name permalink  \
# 0  52cdef7c4bab8bd675297d8a  Wetpaint      abc2
# 1  52cdef7c4bab8bd675297d8c      Zoho      abc4
# 2  52cdef7c4bab8bd675297d8d      Digg      digg
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 1      http://www.crunchbase.com/company/zoho          http://zoho.com
# 2      http://www.crunchbase.com/company/digg      http://www.digg.com
#
#                       blog_url                     blog_feed_url  \
# 0  http://digitalquarters.net/  http://digitalquarters.net/feed/
# 1       http://blogs.zoho.com/        http://blogs.zoho.com/feed
# 2        http://blog.digg.com/   http://blog.digg.com/?feed=rss2
#
#   twitter_username category_code  number_of_employees  ...  \
# 0  BachelrWetpaint           web                 47.0  ...
# 1             zoho      software               1600.0  ...
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %%
#$expr compara con el operador logico q le des
#En este caso pide q deadpooled... se gt founded +3
#$add hace una suma entre el valor d un campo y el numero q pases $add:[<campo>,<# a sumar>]
pd.DataFrame(collection_companies.find({'$and':[{'$expr':{'$gt':['$deadpooled_year',{'$add':['$founded_year',3]}]}},{'founded_year':{'$gte':0}}]}))
# Out:
#                           _id              name         permalink  \
# 0    52cdef7c4bab8bd675297da0          Babelgum          babelgum
# 1    52cdef7c4bab8bd675297dae             Thoof             thoof
# 2    52cdef7c4bab8bd675297db6            Wesabe            wesabe
# 3    52cdef7c4bab8bd675297dbe           Stickam           stickam
# 4    52cdef7c4bab8bd675297dcc          AllPeers          allpeers
# ..                        ...               ...               ...
# 432  52cdef7f4bab8bd67529c470         SpeakSoft         speaksoft
# 433  52cdef7f4bab8bd67529c4c4            Tagito            tagito
# 434  52cdef7f4bab8bd67529c503  Nordic Windpower  nordic-windpower
# 435  52cdef7f4bab8bd67529c5aa    Nethra Imaging    nethra-imaging
# 436  52cdef7f4bab8bd67529c68b           Prolify           prolify
#
#                                         crunchbase_url  \
# 0           http://www.crunchbase.com/company/babelgum
# 1              http://www.crunchbase.com/company/thoof
# ...

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
pd.DataFrame(collection_companies.find({"$and":[{"founded_year":{"$lt":2000}},{"acquisition.price_amount":{"$gt":10000000}}]})).head()
# Out:
#                         _id        name   permalink  \
# 0  52cdef7c4bab8bd675297d90     Postini     postini
# 1  52cdef7c4bab8bd675297deb    SideStep    sidestep
# 2  52cdef7c4bab8bd675297e2c  Recipezaar  recipezaar
# 3  52cdef7c4bab8bd675297e89      PayPal      paypal
# 4  52cdef7c4bab8bd675297e97    Snapfish    snapfish
#
#                                  crunchbase_url               homepage_url  \
# 0     http://www.crunchbase.com/company/postini         http://postini.com
# 1    http://www.crunchbase.com/company/sidestep    http://www.sidestep.com
# 2  http://www.crunchbase.com/company/recipezaar  http://www.recipezaar.com
# 3      http://www.crunchbase.com/company/paypal      http://www.paypal.com
# 4    http://www.crunchbase.com/company/snapfish        http://snapfish.com
#
#                               blog_url blog_feed_url twitter_username  \
# 0                                                                None
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
#Parece q no hay compañias q cumplan esto 
pd.json_normalize(collection_companies.find({"acquisition.acquired_year":{"$gt":2015}},{"_id":0,"name":1,"acquisition":1}).sort("acquisition.price_amount",-1))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Probamos otra fecha para ver q funciona la query
#Normalizamos el campo "acquisition" para verlo bn
pd.json_normalize(collection_companies.find({"acquisition.acquired_year":{"$gt":2005}},{"_id":0,"name":1,"acquisition":1}).sort("acquisition.price_amount",-1))
# Out:
#                          name  acquisition.price_amount  \
# 0        Goodrich Corporation              1.840000e+10
# 1                 BEA Systems              8.500000e+09
# 2                      Navteq              8.100000e+09
# 3            Sun Microsystems              7.400000e+09
# 4                       Pixar              7.400000e+09
# ...                       ...                       ...
# 2429                     ALOT                       NaN
# 2430                   Nellix                       NaN
# 2431  Celestial Semiconductor                       NaN
# 2432                MyChances                       NaN
# 2433          InSound Medical                       NaN
#
#      acquisition.price_currency_code acquisition.term_code  \
# 0                                USD                  None
# 1                                USD                  None
# 2                                USD                  None
# ...

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
pd.DataFrame(collection_companies.find({},{'_id':0,'name':1,'founded_year':1,}).sort('founded_year',-1).limit(10)).head(3)
# Out:
#         name  founded_year
# 0      Fixya          2013
# 1      Wamba          2013
# 2  Advaliant          2013

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
pd.DataFrame(collection_companies.find({'$and':[{"founded_day":{"$lte":7}},{"founded_month":{"$lte":12}}]}).sort("acquisition.price_amount",-1).limit(10)).head(3)
# Out:
#                         _id      name permalink  \
# 0  52cdef7d4bab8bd6752989a1  Netscape  netscape
# 1  52cdef7c4bab8bd675297e89    PayPal    paypal
# 2  52cdef7c4bab8bd675297efe    Zappos    zappos
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/netscape  http://netscape.aol.com
# 1    http://www.crunchbase.com/company/paypal    http://www.paypal.com
# 2    http://www.crunchbase.com/company/zappos    http://www.zappos.com
#
#                             blog_url                            blog_feed_url  \
# 0
# 1
# 2  http://www.blogs.zappos.com/blogs  http://feeds.feedburner.com/ZapposBlogs
#
#   twitter_username category_code  number_of_employees  ...  \
# 0                       software                  NaN  ...
# 1           paypal       finance             300000.0  ...
# 2           zappos           web               1500.0  ...
#
#                                          investments  \
# ...

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
pd.DataFrame(collection_companies.find({'$and':[{"category_code":'web'},{"number_of_employees":{"$gt":4000}}]}).sort('number_of_employees',-1)).head(3)
# Out:
#                         _id      name permalink  \
# 0  52cdef7c4bab8bd6752982a8  Experian  experian
# 1  52cdef7c4bab8bd675297d9b      eBay      ebay
# 2  52cdef7c4bab8bd675297da3    Yahoo!     yahoo
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/experian  http://www.experian.com
# 1      http://www.crunchbase.com/company/ebay          http://ebay.com
# 2     http://www.crunchbase.com/company/yahoo     http://www.yahoo.com
#
#                               blog_url               blog_feed_url  \
# 0  http://www.experian.com/blogs/news/
# 1
# 2                http://ycorpblog.com/  http://ycorpblog.com/feed/
#
#   twitter_username category_code  number_of_employees  ...  \
# 0      ExperianMkt           web                15500  ...
# 1             eBay           web                15000  ...
# 2            Yahoo           web                13600  ...
#
# ...

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
pd.DataFrame(collection_companies.find({"$and":[{"acquisition.price_amount":{"$gt":10000000}},{"acquisition.price_currency_code":"EUR"}]})).head(3)
# Out:
#                         _id               name          permalink  \
# 0  52cdef7c4bab8bd675297f02                ZYB                zyb
# 1  52cdef7d4bab8bd675298bf3            Apertio            apertio
# 2  52cdef7d4bab8bd675298f47  Greenfield Online  greenfield-online
#
#                                       crunchbase_url  \
# 0              http://www.crunchbase.com/company/zyb
# 1          http://www.crunchbase.com/company/apertio
# 2  http://www.crunchbase.com/company/greenfield-o...
#
#                                    homepage_url              blog_url  \
# 0                                http://zyb.com  http://blog.zyb.com/
# 1                        http://www.apertio.com
# 2  http://www.greenfield.com/content/index.html
#
#                          blog_feed_url twitter_username     category_code  \
# 0  http://blog.zyb.com/index.php/feed/             None            mobile
# 1                                                  None            mobile
# ...

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
pd.DataFrame(collection_companies.find({"acquisition.acquired_month":{"$lt":4}},{"_id":0,"name":1,"acquisition":1}).limit(10)).head(3)
# Out:
#          name                                        acquisition
# 0        Kyte  {'price_amount': None, 'price_currency_code': ...
# 1  NetRatings  {'price_amount': 327000000, 'price_currency_co...
# 2      blogTV  {'price_amount': None, 'price_currency_code': ...

# %%
pd.json_normalize(collection_companies.find({"acquisition.acquired_month":{"$lt":4}},{"_id":0,"name":1,"acquisition":1}).limit(10)).head(3)
# Out:
#          name  acquisition.price_amount acquisition.price_currency_code  \
# 0  NetRatings               327000000.0                             USD
# 1      blogTV                       NaN                             USD
# 2  Livestream                       NaN                             USD
#
#   acquisition.term_code                             acquisition.source_url  \
# 0                  cash  http://login.vnuemedia.com/hr/login/login_subs...
# 1                  None  http://techcrunch.com/2013/03/13/younow-buys-b...
# 2        cash_and_stock
#
#                       acquisition.source_description  \
# 0                    Nielsen buys rest of NetRatings
# 1  Live Social Video Network YouNow Acquires Stre...
# 2                                            company
#
#    acquisition.acquired_year  acquisition.acquired_month  \
# 0                       2007                           2
# 1                       2013                           3
# ...

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
pd.DataFrame(collection_companies.find({"$and":[{"founded_year":{"$gte":2000}},{"founded_year":{"$lte":2010}},{"acquisition.acquired_year":{"$gte":2011}}]}))
# Out:
#                           _id                     name  \
# 0    52cdef7c4bab8bd675297d8a                 Wetpaint
# 1    52cdef7c4bab8bd675297d8d                     Digg
# 2    52cdef7c4bab8bd675297d91                     Geni
# 3    52cdef7c4bab8bd675297dab                     Kyte
# 4    52cdef7c4bab8bd675297daf          Jingle Networks
# ..                        ...                      ...
# 481  52cdef7f4bab8bd67529c691                     ALOT
# 482  52cdef7f4bab8bd67529c6b4               OptiMedica
# 483  52cdef7f4bab8bd67529c6c5          Luminus Devices
# 484  52cdef7f4bab8bd67529c6e0  Celestial Semiconductor
# 485  52cdef7f4bab8bd67529c6e2                MyChances
#
#                    permalink  \
# 0                       abc2
# 1                       digg
# 2                       geni
# 3                       kyte
# 4            jingle-networks
# ..                       ...
# 481                     alot
# 482               optimedica
# ...
