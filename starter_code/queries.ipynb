# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
import pandas as pd
client=MongoClient('mongodb+srv://RODHERDAPTM:sbHn9SYR5X8b8C!@cluster0-wp5zp.gcp.mongodb.net/db_companies?retryWrites=true&w=majority')
db=client.db_companies

# %%
print(db)

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
print(list(db['companies'].find({'name':"Babelgum"},{'name':1,'_id':0})))
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
#list(db['companies'].find(filter={'number_of_employees' : {'$gt' : 5000}},sort=[{'number_of_employees': 1}], limit=20))
list(db['companies'].find(filter={'number_of_employees' : {'$gt' : 5000}}
                                ,projection={'name':1,'_id':0,'number_of_employees' : 1}
                                ,sort=[{'number_of_employees': 1}], limit=20))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-011e854278e7> in <module>
#       2 list(db['companies'].find(filter={'number_of_employees' : {'$gt' : 5000}}
#       3                                 ,projection={'name':1,'_id':0,'number_of_employees' : 1}
# ----> 4                                 ,sort=[{'number_of_employees': 1}], limit=20))
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in find(self, *args, **kwargs)
#    1458
#    1459         """
# -> 1460         return Cursor(self, *args, **kwargs)
#    1461
#    1462     def find_raw_batches(self, *args, **kwargs):
#
# ...

# %%
### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
list(db['db_companies'].find(filter={'$and':[{'founded_year':{'$lte':2010}},{'founded_year':{'$gte':2005}}
                                             ,{'name':1,'_id':0,'founded_year':1}]}))
# Out:
# []

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
    list(db['companies'].find(filter = {'$and':[{'founded_year':{'$lt':2010}, "ipo.valuation_amount":{'$gt':100000000}}
                                               ,projection={'name':1,'_id':0,"ipo.valuation_amount":1}]}))
# Out:
#   File "<ipython-input-28-e9623700ab5c>", line 2
#     ],projection={'name':1,'_id':0,"ipo.valuation_amount":1}}))
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
list(db['companies'].find(filter={$and:[{'number_of_employees':{'$lt':1000}}, {'founded_year':{'$lt':2005}},
                                       sort=[(number_of_employees,-1)],limit=(10),
                                       projection={'name':1,'_id':0,'founded_year':1,'number_of_employees':1}]}))
# Out:
#   File "<ipython-input-40-d288a8939e5e>", line 1
#     list(db['companies'].find(filter={$and:[{'number_of_employees':{'$lt':1000}}, {'founded_year':{'$lt':2005}},
#                                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
list(db['companies'].find(filter = {'partners':{'$exists':False}}))
# Out:
# []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
list(db['companies'].find(filter = {'category_code' : {'$eq':None}},projection={'name':1,'_id':0}))
# Out:
# [{'name': 'Collective'},
#  {'name': 'Snimmer'},
#  {'name': 'KoolIM'},
#  {'name': 'Level9 Media'},
#  {'name': 'VidKing'},
#  {'name': 'Drigg'},
#  {'name': 'SpaceTime'},
#  {'name': 'Touch Clarity'},
#  {'name': 'MMDAYS'},
#  {'name': 'Inside Group'},
#  {'name': 'Repeater Store'},
#  {'name': 'Tapesh'},
#  {'name': 'iPersians'},
#  {'name': 'NewPersia'},
#  {'name': 'Pyra Labs'},
#  {'name': 'Feedmap'},
#  {'name': 'NuvoMedia'},
#  {'name': 'Intwine'},
#  {'name': 'The Weinstein Company'},
#  {'name': 'ExecuNet'},
#  {'name': 'A1Vacations'},
#  {'name': 'TripHomes'},
#  {'name': 'Picturehouse'},
#  {'name': 'Covalent Technologies'},
#  {'name': 'Epic Trip'},
#  {'name': 'Telepost'},
#  {'name': 'Fidelity'},
#  {'name': 'Quirk'},
#  {'name': 'Skyrove'},
#  {'name': 'Leechblock'},
#  {'name': 'My Success Gateway'},
#  {'name': 'RealNames'},
#  {'name': 'The Easynet Group'},
#  {'name': 'NetNames'},
#  {'name': 'Sniperoo'},
#  {'name': 'JD Project'},
#  {'name': 'ABC News'},
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
list(db['companies'].find(filter = {{$or:[{'number_of_employees':{'$gt':100}},{'number_of_employees':{'$lt':1000}}]}},
                         projection={{'name':1,'_id':0,'number_of_employees':1}}))
# Out:
#   File "<ipython-input-41-8511b36e4449>", line 1
#     list(db['companies'].find(filter = {{or:[{'number_of_employees':{'$gt':100}},{'number_of_employees':{'$lt':1000}}]}},
#                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
 list(db['companies'].find(projection = {'name':1,'_id':0, "ipo.valuation_amount":1}, 
                           sort = {{'ipo.valuation_amount':-1}}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-773b55ef5ea4> in <module>
#       1 list(db['companies'].find(projection = {'name':1,'_id':0, "ipo.valuation_amount":1},
# ----> 2                           sort = {{'ipo.valuation_amount':-1}}))
#
# TypeError: unhashable type: 'dict'

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
list(db['companies'].find(projection={'name':1,'_id':0, "number_of_employees":1},
                         sort=[{"number_of_employees":-1}], limit=(10)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-212732096664> in <module>
#       1 list(db['companies'].find(projection={'name':1,'_id':0, "number_of_employees":1},
# ----> 2                          sort=[{"number_of_employees":-1}], limit=(10)))
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in find(self, *args, **kwargs)
#    1458
#    1459         """
# -> 1460         return Cursor(self, *args, **kwargs)
#    1461
#    1462     def find_raw_batches(self, *args, **kwargs):
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in __init__(self, collection, filter, projection, skip, limit, no_cursor_timeout, cursor_type, sort, allow_partial_results, oplog_replay, modifiers, batch_size, manipulate, collation, hint, max_scan, max_time_ms, max, min, return_key, show_record_id, snapshot, comment, session)
#     173         self.__batch_size = batch_size
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
list(db['companies'].find(filter={'founded_month':{'$gte':7}},
                          projection={'name':1,'_id':0, 'founded_month':1},limit=(1000)))
# Out:
# [{'name': 'Wetpaint', 'founded_month': 10},
#  {'name': 'Zoho', 'founded_month': 9},
#  {'name': 'Digg', 'founded_month': 10},
#  {'name': 'Omnidrive', 'founded_month': 11},
#  {'name': 'eBay', 'founded_month': 9},
#  {'name': 'Joost', 'founded_month': 10},
#  {'name': 'Plaxo', 'founded_month': 11},
#  {'name': 'Powerset', 'founded_month': 10},
#  {'name': 'Kyte', 'founded_month': 12},
#  {'name': 'Thoof', 'founded_month': 12},
#  {'name': 'Jingle Networks', 'founded_month': 9},
#  {'name': 'LifeLock', 'founded_month': 8},
#  {'name': 'Wesabe', 'founded_month': 12},
#  {'name': 'SmugMug', 'founded_month': 11},
#  {'name': 'Google', 'founded_month': 9},
#  {'name': 'Skype', 'founded_month': 8},
#  {'name': 'Pando Networks', 'founded_month': 7},
#  {'name': 'Ikan', 'founded_month': 12},
#  {'name': 'delicious', 'founded_month': 9},
#  {'name': 'AllPeers', 'founded_month': 8},
#  {'name': 'Wize', 'founded_month': 8},
#  {'name': 'SellABand', 'founded_month': 8},
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
list(db['companies'].find(filter={'founded_year' : {'$lt' : 2000}, "acquisitions.price_amount" : {'$gt' : 10000000}},
                         projection={'name':1,'_id':0,'founded_year':1, "acquisitions.price_amount" :1 }))
# Out:
# [{'name': 'Fox Interactive Media',
#   'founded_year': 1979,
#   'acquisitions': [{'price_amount': 20000000},
#    {'price_amount': 700000000},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None}]},
#  {'name': 'eBay',
#   'founded_year': 1995,
#   'acquisitions': [{'price_amount': 1500000000},
#    {'price_amount': 620000000},
#    {'price_amount': 48300000},
#    {'price_amount': None},
#    {'price_amount': 310000000},
#    {'price_amount': 350000000},
#    {'price_amount': 945000000},
#    {'price_amount': 380000000},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': 415000000},
#    {'price_amount': 290000000},
#    {'price_amount': 50000000},
#    {'price_amount': 150000000},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': 215000000},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
 list(db['companies'].find(filter = {'acquisitions.acquired_year':{'$gt':2015}},
                          projection={'name':1,'_id':0,'founded_year':1,"acquisitions.acquired_year":1}))
# Out:
# []

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
list(db['companies'].find(projection={'name':1,'_id':0,'founded_year':1}
                          #,sort={"founded_year":-1}
                         ))
# Out:
# [{'name': 'Wetpaint', 'founded_year': 2005},
#  {'name': 'AdventNet', 'founded_year': 1996},
#  {'name': 'Zoho', 'founded_year': 2005},
#  {'name': 'Digg', 'founded_year': 2004},
#  {'name': 'Facebook', 'founded_year': 2004},
#  {'name': 'Omnidrive', 'founded_year': 2005},
#  {'name': 'Postini', 'founded_year': 1999},
#  {'name': 'Geni', 'founded_year': 2006},
#  {'name': 'Flektor', 'founded_year': None},
#  {'name': 'Fox Interactive Media', 'founded_year': 1979},
#  {'name': 'Twitter', 'founded_year': 2006},
#  {'name': 'StumbleUpon', 'founded_year': 2002},
#  {'name': 'Gizmoz', 'founded_year': 2003},
#  {'name': 'Scribd', 'founded_year': 2007},
#  {'name': 'Slacker', 'founded_year': 2006},
#  {'name': 'Lala', 'founded_year': None},
#  {'name': 'Helio', 'founded_year': 2005},
#  {'name': 'eBay', 'founded_year': 1995},
#  {'name': 'MeetMoi', 'founded_year': 2007},
#  {'name': 'Joost', 'founded_year': 2006},
#  {'name': 'CBS', 'founded_year': 1986},
# ...

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
list(db['companies'].find(filter={'founded_day':{'$lte':7}},
                         projection={'founded_day':1,'name':1,'_id':0,"acquisitions.price_amount":1},
                         #sort={"acquisitions.price_amount":1}, 
                         limit=10))
# Out:
# [{'name': 'Facebook',
#   'founded_day': 1,
#   'acquisitions': [{'price_amount': None},
#    {'price_amount': 47500000},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': 2500000},
#    {'price_amount': 10000000},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': 60000000},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': 1010470000},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': 50000000},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': None},
#    {'price_amount': 60000000},
#    {'price_amount': None},
# ...

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
list(db['companies'].find(filter={'category_code':"web"},
                         projection={'name':1,'_id':0}))

###FALTA AGREGAR MAYORES A 4000
# Out:
# [{'name': 'Wetpaint'},
#  {'name': 'Postini'},
#  {'name': 'Geni'},
#  {'name': 'Fox Interactive Media'},
#  {'name': 'StumbleUpon'},
#  {'name': 'Gizmoz'},
#  {'name': 'eBay'},
#  {'name': 'Viacom'},
#  {'name': 'Plaxo'},
#  {'name': 'Yahoo!'},
#  {'name': 'Mahalo'},
#  {'name': 'Gannett'},
#  {'name': 'Thoof'},
#  {'name': 'Info'},
#  {'name': 'JotSpot'},
#  {'name': 'Meetup'},
#  {'name': 'Mercora'},
#  {'name': 'NetRatings'},
#  {'name': 'Wesabe'},
#  {'name': 'Jangl SMS'},
#  {'name': 'Ikan'},
#  {'name': 'delicious'},
#  {'name': 'Topix'},
#  {'name': 'Pownce'},
#  {'name': 'AllPeers'},
#  {'name': 'CriticalMetrics'},
#  {'name': 'SodaHead'},
#  {'name': 'Steorn'},
#  {'name': 'ClipBlast!'},
#  {'name': 'Tun3r'},
#  {'name': 'Spotplex'},
#  {'name': 'TripUp'},
#  {'name': 'Wakoopa'},
#  {'name': 'Fleck'},
#  {'name': 'Coghead'},
#  {'name': 'Zamzar'},
#  {'name': 'Zooomr'},
#  {'name': 'SideStep'},
#  {'name': 'coRank'},
#  {'name': 'Pageflakes'},
#  {'name': 'Instructables'},
# ...

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
list(db['companies'].find(filter = {{"acquisition.acquired_month":{'$lte':3}}}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-ae95b546e6c1> in <module>
# ----> 1 list(db['companies'].find(filter = {{"acquisition.acquired_month":{'$lte':3}}}))
#
# TypeError: unhashable type: 'dict'

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.
